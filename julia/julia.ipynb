# %% [markdown]
# # JULIA INTRODUCTION

# %% [markdown]
# linguaggio semplice, unisce un po' C e python, è relativamente veloce con una sintassi simile a python
#
# fornisce tool per calcolo scientifico e data science
#
# ML meno sviluppato
#
# julia è compilato just in time, usa LVM dietro le quinte

# %%
x = 3
# Out:
# 3

# %%
typeof(x)
# Out:
# Int64

# %% [markdown]
# PLOTTING SOME DATA WITH JULIA
# random and broadcasted -0,5

# %%
using Plots

# plot some data

plot([cumsum(rand(500).-0.5), cumsum(rand(500).-0.5)])

# save the current figure
savefig("plots.svg")
# .eps, .pdf, & .png are also supported
# we used svg here because it respects the width and height specified above
# Out:
# "/home/nic/Scrivania/progravanzata/julia/plots.svg"
